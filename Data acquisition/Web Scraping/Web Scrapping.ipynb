# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipcart_url)

# %%
flipcart_page = urlclient.read()

# %%
flipcart_html = bs(flipcart_page,'html.parser')

# %%
flipcart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
main_div = flipcart_html.find_all("div", {"class":"_1AtVbE col-12-12"})

# %%
len(main_div)
# Out:
# 30

# %%
del main_div[0:3]

# %%
productlink = "https://www.flipkart.com" + main_div[0].div.div.div.a['href']

# %%
for i in main_div:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/mi-x-pro-108-cm-43-inch-ultra-hd-4k-led-smart-google-tv-2023-4k-dolby-vision-iq-hdr10-atmos-dts-vivid-picture-engine-2-adaptive-brightness/p/itm36abeceefe212?pid=TVSGZF5Y4H4HGVYW&lid=LSTTVSGZF5Y4H4HGVYWORP0L0&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_4JFVE5k8TcZD0iAgJZtZyPc667YTogeHLLcEFQUANOxYeEwQV3pGD8xM3sH4pcjR_nucaPaWimkGDnIm-Jajp_UFjCTyOHoHZs-Z5_PS_w0%3D&ppt=None&ppn=None&ssid=18py049mio0000001709319385522&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/lg-80-cm-32-inch-hd-ready-led-smart-webos-tv/p/itmb2ff267644902?pid=TVSGC8FKBCFFBFT7&lid=LSTTVSGC8FKBCFFBFT78ATBNW&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=bb2cf031-a823-442e-9821-b1825554e0c2.TVSGC8FKBCFFBFT7.SEARCH&ppt=None&ppn=None&ssid=18py049mio0000001709319385522&qH=c9a1fdac6e082dd8
# ...

# %%
print(productlink)
# Out:
# https://www.flipkart.com/mi-x-pro-108-cm-43-inch-ultra-hd-4k-led-smart-google-tv-2023-4k-dolby-vision-iq-hdr10-atmos-dts-vivid-picture-engine-2-adaptive-brightness/p/itm36abeceefe212?pid=TVSGZF5Y4H4HGVYW&lid=LSTTVSGZF5Y4H4HGVYWORP0L0&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_4JFVE5k8TcZD0iAgJZtZyPc667YTogeHLLcEFQUANOxYeEwQV3pGD8xM3sH4pcjR_nucaPaWimkGDnIm-Jajp_UFjCTyOHoHZs-Z5_PS_w0%3D&ppt=None&ppn=None&ssid=18py049mio0000001709319385522&qH=c9a1fdac6e082dd8

# %%
product_req = requests.get(productlink)

# %%
product_html = bs(product_req.text)

# %%
comment_box  = product_html.find_all("div",{"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p",{"class": "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Jayaraman Desingou'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class": "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Jayaraman Desingou
# Rajesh G
# sachin patel
# Rajib Sain
# RISHU SINGH
# Jidesh C
# Khushan Ray
# Gopi Gopinadh
# Lijil Lakshmanan
# LIONUMA
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RISHAB~1\AppData\Local\Temp/ipykernel_8716/3795749955.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class": "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 4
# 5
# 4
# 5
# 4
# 5
# 5
# 5
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RISHAB~1\AppData\Local\Temp/ipykernel_8716/2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.p.text)
# Out:
# Wonderful
# Wonderful
# Brilliant
# Very Good
# Great product
# Wonderful
# Mind-blowing purchase
# Classy product
# Awesome
# Delightful
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RISHAB~1\AppData\Local\Temp/ipykernel_8716/477538510.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.find_all('div',{"class":""})[0].text)
# Out:
# Very good TV. Decent picture quality and sound effect. Value for money. I am just expecting this TV to work for 4 years.READ MORE
# Such a nice design. Sound quality improved alot compared to 4x.  Picture quality is satisfying.READ MORE
# Product is very very awesome .Picture quality  upto mark .Sound quality value for money .Delivery and installation are more than my expectation(awesome).Note : installation same day that day tv delivered and delivery persons are too good as behavior. So , my recommendation to who want MI to buy this Thank you MI 😊READ MORE
# Good TV with nice looks and feature. Worthy for the budget segment to which it belongs. However picture could have been more crisper especially for the non-4k contents. But definitely a worthy buy in this price segment.READ MORE
# Very Excellent productPicture quality ExcellentViewing angle very good Sound quality goodBuild quality parfectNo doubt Value for moneyLooking vary expensiveREAD MORE
# ...
